# %% [markdown]
# # Chapter 6

# %%
from statistics import mean , stdev , median

# %%
data = [19, 29, 29, 30, 34, 36, 39, 47, 51, 52, 53, 60,
60, 64, 66, 68, 70]

# %%
print(mean(data))
# Out:
# 47.470588235294116

# %%
print(stdev(data))
# Out:
# 16.019978335889

# %%
print(median(data))
# Out:
# 51

# %%
from random import choices

# %%
v = ["A", "B", "C", "D", "E", "F"]

# %%
print(choices(v, k=len(v)))
# Out:
# ['F', 'E', 'B', 'A', 'B', 'B']

# %%
print(choices(v, k=len(v)))
# Out:
# ['A', 'A', 'A', 'E', 'D', 'E']

# %%
print(choices(v, k=len(v)))
# Out:
# ['C', 'C', 'F', 'B', 'E', 'B']

# %%
def bootstrap_se(data, func, reps):
	theta_hat_stars = []
	for i in range(reps):
		resample = choices(data, k=len(data))
		theta_hat_star = func(resample)
		theta_hat_stars.append(theta_hat_star)
	return stdev(theta_hat_stars)

# %%
print(bootstrap_se(data, mean, 50000))
# Out:
# 3.7644654220402507

# %%
print(bootstrap_se(data, mean, 50000))
# Out:
# 3.758144366951801

# %%
import pandas as pd

# Load a CSV file
df = pd.read_csv('data/NCBirths2004.csv')

# Now 'df' is a DataFrame containing the data from the file

# %%
print(df)
# Out:
#         ID MothersAge Smoker Alcohol  Gender  Weight  Gestation
# 0        1      30-34     No      No    Male    3827         40
# 1        2      30-34     No      No    Male    3629         38
# 2        3      35-39     No      No  Female    3062         37
# 3        4      20-24     No      No  Female    3430         39
# 4        5      25-29     No      No    Male    3827         38
# ...    ...        ...    ...     ...     ...     ...        ...
# 1004  1005      35-39     No      No    Male    3799         39
# 1005  1006      20-24     No      No    Male    2835         39
# 1006  1007      15-19     No      No    Male    3260         38
# 1007  1008      20-24     No      No  Female    2637         41
# 1008  1009      20-24     No      No  Female    3005         39
#
# [1009 rows x 7 columns]

# %%
# Using bracket notation
weights = df.Weight

print(weights)
# Out:
# 0       3827
# 1       3629
# 2       3062
# 3       3430
# 4       3827
#         ...
# 1004    3799
# 1005    2835
# 1006    3260
# 1007    2637
# 1008    3005
# Name: Weight, Length: 1009, dtype: int64

# %%
# bootstrap 

theta_hat_stars = []

for i in range(10000):
	resample = choices(weights, k=1009)
	theta_hat_star = mean(resample)
	theta_hat_stars.append(theta_hat_star)

# %%
print(theta_hat_stars)
# Out:
